# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.ticker import MultipleLocator

# %%
#fig1, ax = plt.subplots(figsize=(15, 6))
#plt.errorbar(x,y,yerr=err,fmt='w.',ecolor='w',mew=0,ms=0,elinewidth=0.5)
#ax.set_axis_bgcolor((0, 0, 0))
#plt.axis([ min(x)*1.01, max(x)*1.01, min(y)*0.994, max(y) ])

# %% [markdown]
# # Tránsito b

# %%
data = open( 'TRAPPIST-1b.dat', 'r' )
lines = data.readlines( )
splitted = [] 
for i in range(len(lines)):
    splitted.append(lines[i].split())
x=np.zeros(len(lines))
y=np.zeros(len(lines))
err=np.zeros(len(lines))
for i in range(len(splitted)):
    x[i]+=float(splitted[i][0])
    y[i]+=float(splitted[i][1])
    err[i]+=float(splitted[i][2])

# %%
fig1, ax = plt.subplots(figsize=(20, 7))
plt.errorbar(x,y,yerr=err,fmt='k.',ecolor='k',mew=0.1,ms=0,elinewidth=0.3)
plt.scatter(x[:206],y[:206],c='m',s=15,label='TRAPPIST',edgecolors='face')
plt.scatter(x[207:310],y[207:310],c='b',s=15,label='HCT/HFOSC',edgecolors='face')
plt.scatter(x[311:445],y[311:445],c='r',s=15,label='UKIRT/WFCAM',edgecolors='face')
plt.scatter(x[445:],y[445:],c='g',s=15,label='VLT/HAWKI',edgecolors='face')
#ax.set_axis_bgcolor((0, 0, 0))

plt.legend(loc=4)


plt.rc('text', usetex=True) #Tex eneable
plt.rc('font', family='serif') #Set font to serif-like font.

plt.xlabel(r'Time from mid-transit (day)',fontsize=20)
plt.ylabel(r'Flux',fontsize=20)
plt.title(r'TRAPPIST-1b',fontsize=20)
matplotlib.rcParams.update({'font.size': 15})

plt.axis([ min(x), max(x)*1.05, min(y)*0.99, max(y)*1.001 ]) 
plt.show()

# %% [markdown]
# # Tránsito c

# %%
data = open( 'TRAPPIST-1c.dat', 'r' )
lines = data.readlines( )
splitted = [] 
for i in range(len(lines)):
    splitted.append(lines[i].split())
x=np.zeros(len(lines))
y=np.zeros(len(lines))
err=np.zeros(len(lines))
for i in range(len(splitted)):
    x[i]+=float(splitted[i][0])
    y[i]+=float(splitted[i][1])
    err[i]+=float(splitted[i][2])

# %%
fig1, ax = plt.subplots(figsize=(20, 7))
plt.errorbar(x,y,yerr=err,fmt='k.',ecolor='k',mew=0.1,ms=0,elinewidth=0.3)
plt.scatter(x[:241],y[:241],c='b',s=15,label='TRAPPIST',edgecolors='face')
plt.scatter(x[242:],y[242:],c='r',s=15,label='UKIRT/WFCAM',edgecolors='face')
#ax.set_axis_bgcolor((0, 0, 0))

plt.legend(loc=4)


plt.rc('text', usetex=True) #Tex eneable
plt.rc('font', family='serif') #Set font to serif-like font.

plt.xlabel(r'Time from mid-transit (day)',fontsize=20)
plt.ylabel(r'Flux',fontsize=20)
plt.title(r'TRAPPIST-1c',fontsize=20)
matplotlib.rcParams.update({'font.size': 15})

plt.axis([ min(x), max(x)*1.05, min(y)*0.99, max(y)*1.001 ]) 
plt.show()

# %% [markdown]
# # Tránsito d(1)

# %%
data = open( 'TRAPPIST-1d(1).dat', 'r' )
lines = data.readlines( )
splitted = [] 
for i in range(len(lines)):
    splitted.append(lines[i].split())
x=np.zeros(len(lines))
y=np.zeros(len(lines))
err=np.zeros(len(lines))
for i in range(len(splitted)):
    x[i]+=float(splitted[i][0])
    y[i]+=float(splitted[i][1])
    err[i]+=float(splitted[i][2])

# %%
fig1, ax = plt.subplots(figsize=(20, 7))
plt.errorbar(x,y,yerr=err,fmt='k.',ecolor='k',mew=0.1,ms=0,elinewidth=0.3)
plt.scatter(x,y,c='k',s=15,label='TRAPPIST',edgecolors='face')
#ax.set_axis_bgcolor((0, 0, 0))
plt.legend(loc=4)


plt.rc('text', usetex=True) #Tex eneable
plt.rc('font', family='serif') #Set font to serif-like font.

plt.xlabel(r'Time from mid-transit (day)',fontsize=20)
plt.ylabel(r'Flux',fontsize=20)
plt.title(r'TRAPPIST-1d',fontsize=20)
matplotlib.rcParams.update({'font.size': 15})

plt.axis([ min(x)*0.9, max(x)*1.05, min(y)*0.99, max(y)*1.001 ]) 
plt.show()

# %% [markdown]
# # Tránsito d(2)

# %%
data = open( 'TRAPPIST-1d(2).dat', 'r' )
lines = data.readlines( )
splitted = [] 
for i in range(len(lines)):
    splitted.append(lines[i].split())
x=np.zeros(len(lines))
y=np.zeros(len(lines))
err=np.zeros(len(lines))
for i in range(len(splitted)):
    x[i]+=float(splitted[i][0])
    y[i]+=float(splitted[i][1])
    err[i]+=float(splitted[i][2])

# %%
fig1, ax = plt.subplots(figsize=(25, 10))
plt.errorbar(x,y,yerr=err,fmt='k.',ecolor='k',mew=0.02,ms=0,elinewidth=0.3)

plt.scatter(x[:38],y[:38],c='b',s=15,label='TRAPPIST-South',edgecolors='face')

plt.scatter(x[39:107],y[39:107],c='r',s=15,label='WHT',edgecolors='face')

plt.scatter(x[108:163],y[108:163],c='b',s=15,edgecolors='face')

plt.scatter(x[164:1063],y[164:1063],c='g',s=15,label='Spitzer',edgecolors='face')

plt.scatter(x[1064:],y[1064:],c='b',s=15,edgecolors='face')

plt.legend(loc=4)

plt.rc('text', usetex=True) #Tex eneable
plt.rc('font', family='serif') #Set font to serif-like font.

plt.xlabel(r'Time from mid-transit (day)',fontsize=20)
plt.ylabel(r'Flux',fontsize=20)
plt.title(r'TRAPPIST-1d',fontsize=20)
matplotlib.rcParams.update({'font.size': 15})

plt.axis([ min(x)*0.9, max(x)*1.05, min(y)*0.999, max(y)*1.001 ]) 
plt.show()

# %% [markdown]
# # Tránsito e

# %%
data = open( 'TRAPPIST-1e.dat', 'r' )
lines = data.readlines( )
splitted = [] 
for i in range(len(lines)):
    splitted.append(lines[i].split())
x=np.zeros(len(lines))
y=np.zeros(len(lines))
err=np.zeros(len(lines))
for i in range(len(splitted)):
    x[i]+=float(splitted[i][0])
    y[i]+=float(splitted[i][1])
    err[i]+=float(splitted[i][2])

# %%
fig1, ax = plt.subplots(figsize=(25, 8))
plt.errorbar(x,y,yerr=err,fmt='k.',ecolor='k',mew=0.02,ms=0,elinewidth=0.3)

plt.scatter(x[:65],y[:65],c='b',s=15,label='TRAPPIST-South',edgecolors='face')

plt.scatter(x[66:86],y[66:86],c='r',s=15,label='VLT/HAWK-I',edgecolors='face')

plt.scatter(x[87:114],y[87:114],c='m',s=15,label='TRAPPIST-North',edgecolors='face')

plt.scatter(x[115:152],y[115:152],c='b',s=15,edgecolors='face')

plt.scatter(x[153:287],y[153:287],c='g',s=15,label='Spitzer',edgecolors='face')

plt.scatter(x[288:314],y[288:314],c='b',s=15,edgecolors='face')

plt.scatter(x[315:359],y[315:359],c='k',s=15,label='LT',edgecolors='face')

plt.scatter(x[360:],y[360:],c='b',s=15,edgecolors='face')


plt.legend(loc=4)

plt.rc('text', usetex=True) #Tex eneable
plt.rc('font', family='serif') #Set font to serif-like font.

plt.xlabel(r'Time from mid-transit (day)',fontsize=20)
plt.ylabel(r'Flux',fontsize=20)
plt.title(r'TRAPPIST-1e',fontsize=20)
matplotlib.rcParams.update({'font.size': 15})

plt.axis([ min(x)*0.9, max(x)*1.05, min(y)*0.999, max(y)*1.001 ]) 
plt.show()

# %% [markdown]
# # Tránsito f

# %%
data = open( 'TRAPPIST-1f.dat', 'r' )
lines = data.readlines( )
splitted = [] 
for i in range(len(lines)):
    splitted.append(lines[i].split())
x=np.zeros(len(lines))
y=np.zeros(len(lines))
err=np.zeros(len(lines))
for i in range(len(splitted)):
    x[i]+=float(splitted[i][0])
    y[i]+=float(splitted[i][1])
    err[i]+=float(splitted[i][2])

# %%
fig1, ax = plt.subplots(figsize=(25, 8))
plt.errorbar(x,y,yerr=err,fmt='k.',ecolor='k',mew=0.02,ms=0,elinewidth=0.3)

plt.scatter(x[:40],y[:40],c='b',s=15,label='TRAPPIST-South',edgecolors='face')

plt.scatter(x[41:61],y[41:61],c='r',s=15,label='VLT/HAWK-I',edgecolors='face')

plt.scatter(x[62:92],y[62:92],c='b',s=15,edgecolors='face')

plt.scatter(x[93:145],y[93:145],c='k',s=15,label='LT',edgecolors='face')

plt.scatter(x[146:],y[146:],c='g',s=15,label='Spitzer',edgecolors='face')

plt.legend(loc=4)

plt.rc('text', usetex=True) #Tex eneable
plt.rc('font', family='serif') #Set font to serif-like font.

plt.xlabel(r'Time from mid-transit (day)',fontsize=20)
plt.ylabel(r'Flux',fontsize=20)
plt.title(r'TRAPPIST-1f',fontsize=20)
matplotlib.rcParams.update({'font.size': 15})

plt.axis([ min(x)*0.9, max(x)*1.05, min(y)*0.999, max(y)*1.001 ]) 
plt.show()

# %% [markdown]
# # Tránsito g

# %%
data = open( 'TRAPPIST-1g.dat', 'r' )
lines = data.readlines( )
splitted = [] 
for i in range(len(lines)):
    splitted.append(lines[i].split())
x=np.zeros(len(lines))
y=np.zeros(len(lines))
err=np.zeros(len(lines))
for i in range(len(splitted)):
    x[i]+=float(splitted[i][0])
    y[i]+=float(splitted[i][1])
    err[i]+=float(splitted[i][2])

# %%
fig1, ax = plt.subplots(figsize=(25, 8))
plt.errorbar(x,y,yerr=err,fmt='k.',ecolor='k',mew=0.02,ms=0,elinewidth=0.3)

plt.scatter(x[:138],y[:138],c='b',s=15,label='TRAPPIST-South',edgecolors='face')

plt.scatter(x[139:],y[139:],c='g',s=15,label='Spitzer',edgecolors='face')

plt.legend(loc=4)

plt.rc('text', usetex=True) #Tex eneable
plt.rc('font', family='serif') #Set font to serif-like font.

plt.xlabel(r'Time from mid-transit (day)',fontsize=20)
plt.ylabel(r'Flux',fontsize=20)
plt.title(r'TRAPPIST-1g',fontsize=20)
matplotlib.rcParams.update({'font.size': 15})

plt.axis([ min(x)*0.9, max(x)*1.05, min(y)*0.999, max(y)*1.001 ]) 
plt.show()

# %% [markdown]
# # Curva de luz completa:

# %%
data = open( 'spitzer.dat', 'r' )
lines = data.readlines( )
splitted = [] 
for i in range(len(lines)):
    splitted.append(lines[i].split())
x=np.zeros(len(lines))
y=np.zeros(len(lines))
err=np.zeros(len(lines))
for i in range(len(splitted)):
    x[i]+=float(splitted[i][0])
    y[i]+=float(splitted[i][1])
    err[i]+=float(splitted[i][2])

# %%
fig1, ax = plt.subplots(figsize=(40, 7))
#plt.errorbar(x,y,yerr=err,fmt='k.',ecolor='k',mew=0.1,ms=0,elinewidth=0.3)
plt.axvspan(7655.95,7656, facecolor='#2ca02c', alpha=0.1)
plt.axvspan(7659.35,7659.45, facecolor='#2ca02c', alpha=0.1)
plt.axvspan(7667.10,7667.15, facecolor='#2ca02c', alpha=0.1)

plt.scatter(x,y,c='k',s=1,label='TRAPPIST',edgecolors='face')
#ax.set_axis_bgcolor((0, 0, 0))



#plt.legend(loc=4)


plt.rc('text', usetex=True) #Tex eneable
plt.rc('font', family='serif') #Set font to serif-like font.

plt.xlabel(r'BJD',fontsize=30)
plt.ylabel(r'Flux',fontsize=30)
plt.title(r'TRAPPIST-1',fontsize=30)
matplotlib.rcParams.update({'font.size': 20})

plt.axis([ min(x), max(x), min(y), max(y) ]) 

xmajorLocator = MultipleLocator(1) 
xminorLocator = MultipleLocator(0.5) 
ymajorLocator = MultipleLocator(0.005) 
yminorLocator = MultipleLocator(0.0025) 

ax.xaxis.set_major_locator( xmajorLocator )
ax.xaxis.set_minor_locator( xminorLocator )
ax.yaxis.set_major_locator( ymajorLocator )
ax.yaxis.set_minor_locator( yminorLocator )

ax.xaxis.grid(True, which='minor',color='k',linewidth=0.1,linestyle='-')
#ax.xaxis.grid(True, which='major',color='k',linewidth=0.4,linestyle='-')

ax.yaxis.grid(True, which='minor',color='k',linewidth=0.2,linestyle='-')
#ax.yaxis.grid(True, which='major',color='k',linewidth=0.4,linestyle='-')

plt.tick_params('both', length=5, width=2, which='major')
plt.tick_params('both', length=0, width=1, which='minor')

#plt.tick_params(axis='both', which='major', labelsize=20)
#plt.tick_params(axis='both', which='minor', labelsize=10)

plt.show()
